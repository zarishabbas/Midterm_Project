# %% [markdown]
# # Parse probability of birdstrike by airport

# %% [markdown]
# ### import data and packages

# %%
import pandas as pd

# %%
# read dat file (as csv) into memory as dataframe

# df = pd.read_csv('airports.dat', index_col=0, names=['1', 'name', 'city', 'country', 'IATA', 'ICAO', 'lat', 'lon', 'alt', 'tz', 'dst', 'dbtz', 'type', 'source'])
# df = df.reset_index()
# df.drop(['1'], axis=1, inplace=True)

# I found a better datasource - see below

# %%
# import CSV file to memory as pandas dataframe

df = pd.read_csv('airports.csv')

# %%
# preview dataframe to ensure data came thru ok

df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN     00AR

# %%
# read list of airports that exist in flights table from text

airport_list = tailno_list = open("airports.txt").read().splitlines()

# %%
# instantiate collector dataframe

airports = pd.DataFrame(columns=df.columns)

# %% [markdown]
# ### filter dataset

# %%
# iterate through target airport codes, adding valid rows to collector dataframe

for airport in airport_list:
    airports = pd.concat([airports, df[df.iata_code == airport]], ignore_index=True)

# %%
airports
# Out:
#        id ident            type                                        name  \
# 0    3679  KMFR  medium_airport  Rogue Valley International Medford Airport
# 1    3416  KBLI  medium_airport            Bellingham International Airport
# 2    3843  KRDM  medium_airport                               Roberts Field
# 3    3872  KSCK  medium_airport               Stockton Metropolitan Airport
# 4    3946  KVLD  medium_airport                   Valdosta Regional Airport
# ..    ...   ...             ...                                         ...
# 370  3899  KSRQ  medium_airport    Sarasota Bradenton International Airport
# 371  3948  KVPS  medium_airport            Destin-Fort Walton Beach Airport
# 372  3547  KFWA  medium_airport            Fort Wayne International Airport
# 373  3847  KRIC   large_airport              Richmond International Airport
# 374  3630  KLAR  medium_airport                    Laramie Regional Airport
#
#      latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0       42.374199    -122.873001        1335.0       NaN          US
# 1       48.792801    -122.538002         170.0       NaN          US
# 2       44.254101    -121.150001        3080.0       NaN          US
# 3       37.894199    -121.237999          33.0       NaN          US
# 4       30.782499     -83.276703         203.0       NaN          US
# ..            ...            ...           ...       ...         ...
# 370     27.395399     -82.554398          30.0       NaN          US
# 371     30.483200     -86.525398          87.0       NaN          US
# 372     40.978500     -85.195099         814.0       NaN          US
# 373     37.505199     -77.319702         167.0       NaN          US
# 374     41.312099    -105.675003        7284.0       NaN          US
#
#     iso_region        municipality scheduled_service gps_code iata_code  \
# 0        US-OR             Medford               yes     KMFR       MFR
# 1        US-WA          Bellingham               yes     KBLI       BLI
# 2        US-OR             Redmond               yes     KRDM       RDM
# 3        US-CA            Stockton                no     KSCK       SCK
# 4        US-GA            Valdosta               yes     KVLD       VLD
# ..         ...                 ...               ...      ...       ...
# 370      US-FL  Sarasota/Bradenton               yes     KSRQ       SRQ
# 371      US-FL          Valparaiso               yes     KVPS       VPS
# 372      US-IN          Fort Wayne               yes     KFWA       FWA
# 373      US-VA            Richmond               yes     KRIC       RIC
# 374      US-WY             Laramie               yes     KLAR       LAR
#
#     local_code                      home_link  \
# 0          MFR                            NaN
# 1          BLI                            NaN
# 2          RDM                            NaN
# 3          SCK  http://www.sjgov.org/airport/
# 4          VLD                            NaN
# ..         ...                            ...
# 370        SRQ                            NaN
# 371        VPS         http://www.flyvps.com/
# 372        FWA         https://fwairport.com/
# 373        RIC                            NaN
# 374        LAR                            NaN
#
#                                         wikipedia_link    keywords
# 0    https://en.wikipedia.org/wiki/Rogue_Valley_Int...         NaN
# 1    https://en.wikipedia.org/wiki/Bellingham_Inter...         NaN
# 2          https://en.wikipedia.org/wiki/Roberts_Field         NaN
# 3    https://en.wikipedia.org/wiki/Stockton_Metropo...         NaN
# 4    https://en.wikipedia.org/wiki/Valdosta_Regiona...         NaN
# ..                                                 ...         ...
# 370  https://en.wikipedia.org/wiki/Sarasota-Bradent...         NaN
# 371  https://en.wikipedia.org/wiki/Destin%E2%80%93F...   Eglin AFB
# 372  https://en.wikipedia.org/wiki/Fort_Wayne_Inter...  Baer Field
# 373  https://en.wikipedia.org/wiki/Richmond_Interna...         NaN
# 374  https://en.wikipedia.org/wiki/Laramie_Regional...         NaN
#
# [375 rows x 18 columns]

# %% [markdown]
# ### hub/not hub

# %%
# instantiate a list of hub airports

hubs = ['ANC', 'PHX', 'BUR', 'LAX', 'OAK', 'SAN', 'SFO', 'SJC', 'DEN', 'FLL', 'MCO', 'TPA', 'SFB', 'ATL', 'HNL', 'OGG', 'BOI', 'MDW', 'ORD', 'IND', 'CVG', 'SDF', 'BWI', 'BOS', 'DTW', 'MSP', 'STL', 'LAS', 'ACY', 'EWR', 'TTN', 'JFK', 'LGA', 'CLT', 'GSO', 'RDU', 'CLE', 'LUK', 'DAY', 'PDX', 'PHL', 'PIT', 'CHS', 'CAE', 'MEM', 'BNA', 'DFW', 'DAL', 'IAH', 'SLC', 'ORF', 'IAD', 'DCA', 'SEA']

# %%
# instantiate new column for hub, fill with 0

airports['hub'] = 0

# %%
# change 'type' to 'hub' if IATA code matches our list of hubs

airports.loc[airports.iata_code.isin(hubs), 'hub'] = 1

# %%
# verify above change

airports.hub.value_counts()
# Out:
# 0    322
# 1     53
# Name: hub, dtype: int64

# %% [markdown]
# ### region

# %%
# convert iso_region to region (N - North East W - West M - Mid West S - South O - Other)

states = {
        'US-AK': 'O',
        'US-AL': 'S',
        'US-AR': 'S',
        'US-AS': 'O',
        'US-AZ': 'W',
        'US-CA': 'W',
        'US-CO': 'W',
        'US-CT': 'N',
        'US-DC': 'N',
        'US-DE': 'N',
        'US-FL': 'S',
        'US-GA': 'S',
        'US-GU': 'O',
        'US-HI': 'O',
        'US-IA': 'M',
        'US-ID': 'W',
        'US-IL': 'M',
        'US-IN': 'M',
        'US-KS': 'M',
        'US-KY': 'S',
        'US-LA': 'S',
        'US-MA': 'N',
        'US-MD': 'N',
        'US-ME': 'N',
        'US-MI': 'W',
        'US-MN': 'M',
        'US-MO': 'M',
        'US-MP': 'O',
        'US-MS': 'S',
        'US-MT': 'W',
        'US-NA': 'O',
        'US-NC': 'S',
        'US-ND': 'M',
        'US-NE': 'W',
        'US-NH': 'N',
        'US-NJ': 'N',
        'US-NM': 'W',
        'US-NV': 'W',
        'US-NY': 'N',
        'US-OH': 'M',
        'US-OK': 'S',
        'US-OR': 'W',
        'US-PA': 'N',
        'US-PR': 'O',
        'US-RI': 'N',
        'US-SC': 'S',
        'US-SD': 'M',
        'US-TN': 'S',
        'US-TX': 'S',
        'US-UT': 'W',
        'US-VA': 'S',
        'US-VI': 'O',
        'US-VT': 'N',
        'US-WA': 'W',
        'US-WI': 'M',
        'US-WV': 'S',
        'US-WY': 'W',
        'PR-U-A': 'O',
        'MP-U-A': 'O',
        'VI-U-A': 'O',
        'AS-WT': 'O',
        'GU-U-A': 'O',}

airports['iso_region'].replace(states, inplace=True)

# %%
# verify values

airports.iso_region.value_counts()
# Out:
# S    113
# W    109
# M     69
# N     47
# O     37
# Name: iso_region, dtype: int64

# %%
# rename column to drop iso prefix

airports.rename({'iso_region':'region'}, axis=1, inplace=True)

# %%
# drop irrelevant columns

airports.drop(['id', 'ident', 'name', 'latitude_deg', 'longitude_deg', 'elevation_ft', 'continent', 'iso_country', 'municipality', 'scheduled_service', 'gps_code', 'local_code', 'wikipedia_link', 'keywords', 'hub', 'home_link'], axis=1, inplace=True)

# %%
airports
# Out:
#                type region iata_code
# 0    medium_airport      W       MFR
# 1    medium_airport      W       BLI
# 2    medium_airport      W       RDM
# 3    medium_airport      W       SCK
# 4    medium_airport      S       VLD
# ..              ...    ...       ...
# 370  medium_airport      S       SRQ
# 371  medium_airport      S       VPS
# 372  medium_airport      M       FWA
# 373   large_airport      S       RIC
# 374  medium_airport      W       LAR
#
# [375 rows x 3 columns]

# %% [markdown]
# ### calculate number of birdstrikes and number of flights per airport

# %%
# import flights_by_IATA.csv, containing number of flights in dataset per airport

flights = pd.read_csv('flights_by_IATA.csv', index_col=0)

# %%
# reverse column order for readability

flights = flights[flights.columns[::-1]]

# %%
flights
# Out:
#     IATA  numflights
# 0    ABE       12027
# 1    ABI        4291
# 2    ABQ       54363
# 3    ABR        1492
# 4    ABY        2020
# ..   ...         ...
# 371  XWA         418
# 372  YAK        1442
# 373  YKM        2514
# 374  YNG           2
# 375  YUM        3295
#
# [376 rows x 2 columns]

# %%
# import birdstrike.csv, containing all birdstrikes between 2018-2019

strikes = pd.read_csv('birdstrike.csv', index_col=0)

# %%
strikes
# Out:
#          FLT  OPID INCIDENT_DATE    TIME TIME_OF_DAY AIRPORT_ID  LATITUDE  \
# 0       2502   QXE     2019-12-31  12:30         Day       KSJC  37.36186
# 1        508   HAL     2019-12-31  17:51         Day       PHNL  21.31869
# 2              UNK     2019-12-31  16:16         NaN       KDFW  32.89595
# 3             USCG     2019-12-31  16:55         Day       KPIE  27.91076
# 4              UNK     2019-12-31  09:00         NaN       KLGA  40.77724
# ...      ...   ...            ...    ...         ...        ...       ...
# 33597          UNK     2018-01-01                NaN       KMLI  41.44853
# 33598          UNK     2018-01-01                NaN       KLIT  34.72940
# 33599          UNK     2018-01-01                NaN       KSRQ  27.39533
# 33600          UNK     2018-01-01                NaN       KDFW  32.89595
# 33601    340   AAY     2018-01-01  12:30         Day       KMFR  42.37423
#
#        LONGITUDE FAAREGION  COUNT
# 0     -121.92901      AWP       1
# 1     -157.92241      AWP       1
# 2      -97.03720      ASW       1
# 3      -82.68744      ASO       2
# 4      -73.87261      AEA       1
# ...          ...       ...    ...
# 33597  -90.50754      AGL       1
# 33598  -92.22425      ASW       1
# 33599  -82.55411      ASO       1
# 33600  -97.03720      ASW       1
# 33601 -122.87350      ANM       1
#
# [33602 rows x 10 columns]

# %%
# calculate number of strikes per airport

strikes_byap = strikes.groupby('AIRPORT_ID').sum().reset_index()

# %%
# clear first digit from AIRPORT_ID to match flights DataFrame

strikes_byap['AIRPORT_ID'] = strikes_byap['AIRPORT_ID'].str[-3:]

# %%
# merge dataframes

birdstrike = flights.merge(strikes_byap, how='left', left_on='IATA', right_on='AIRPORT_ID')

# %%
birdstrike
# Out:
#     IATA  numflights AIRPORT_ID     LATITUDE    LONGITUDE  COUNT
# 0    ABE       12027        ABE  2805.012840 -5205.387600   87.0
# 1    ABE       12027        ABE   303.898900  -809.190000    5.0
# 2    ABI        4291        ABI   259.290560  -797.455200    8.0
# 3    ABQ       54363        ABQ  1857.131660 -5650.287070   69.0
# 4    ABR        1492        ABR   772.634020 -1673.171110   21.0
# ..   ...         ...        ...          ...          ...    ...
# 376  XWA         418        XWA    96.521728  -207.502278    2.0
# 377  YAK        1442        NaN          NaN          NaN    NaN
# 378  YKM        2514        YKM   139.704510  -361.632180    3.0
# 379  YNG           2        YNG   123.782220  -242.037300    3.0
# 380  YUM        3295        NaN          NaN          NaN    NaN
#
# [381 rows x 6 columns]

# %%
# Fill NaN birdstrike counts with value 0

birdstrike['COUNT'] = birdstrike['COUNT'].fillna(0)

# %%
# verify fill NaN with 0

birdstrike.COUNT.isna().value_counts()
# Out:
# False    381
# Name: COUNT, dtype: int64

# %%
# drop irrelevant columns

birdstrike.drop(['AIRPORT_ID', 'LATITUDE', 'LONGITUDE'], axis=1, inplace=True)

# %%
# rename COUNT column for readability

birdstrike.rename({'COUNT' : 'numstrikes'}, axis=1, inplace=True)

# %%
birdstrike
# Out:
#     IATA  numflights  numstrikes
# 0    ABE       12027        87.0
# 1    ABE       12027         5.0
# 2    ABI        4291         8.0
# 3    ABQ       54363        69.0
# 4    ABR        1492        21.0
# ..   ...         ...         ...
# 376  XWA         418         2.0
# 377  YAK        1442         0.0
# 378  YKM        2514         3.0
# 379  YNG           2         3.0
# 380  YUM        3295         0.0
#
# [381 rows x 3 columns]

# %% [markdown]
# ### merge numflights / numstrikes with airport dataframe

# %%
# merge the two dataframes using IATA_code

airports = birdstrike.merge(airports, how='left', left_on='IATA', right_on='iata_code')

# %%
# drop duplicate column

airports.drop(['iata_code'], axis=1, inplace=True)

# %%
airports
# Out:
#     IATA  numflights  numstrikes            type region
# 0    ABE       12027        87.0  medium_airport      N
# 1    ABE       12027         5.0  medium_airport      N
# 2    ABI        4291         8.0  medium_airport      S
# 3    ABQ       54363        69.0  medium_airport      W
# 4    ABR        1492        21.0  medium_airport      M
# ..   ...         ...         ...             ...    ...
# 376  XWA         418         2.0  medium_airport      M
# 377  YAK        1442         0.0  medium_airport      O
# 378  YKM        2514         3.0  medium_airport      W
# 379  YNG           2         3.0  medium_airport      M
# 380  YUM        3295         0.0  medium_airport      W
#
# [381 rows x 5 columns]

# %% [markdown]
# ### calculate probability of birdstrike / percentage of total flights

# %%
# initialize new columns, calculate

total_flights = airports.numflights.sum()

airports['strikeprob'] = airports.numstrikes / airports.numstrikes.sum()
airports['percentflights'] = airports.numflights / total_flights

# %%
airports
# Out:
#     IATA  numflights  numstrikes            type region  strikeprob  \
# 0    ABE       12027        87.0  medium_airport      N    0.001977
# 1    ABE       12027         5.0  medium_airport      N    0.000114
# 2    ABI        4291         8.0  medium_airport      S    0.000182
# 3    ABQ       54363        69.0  medium_airport      W    0.001568
# 4    ABR        1492        21.0  medium_airport      M    0.000477
# ..   ...         ...         ...             ...    ...         ...
# 376  XWA         418         2.0  medium_airport      M    0.000045
# 377  YAK        1442         0.0  medium_airport      O    0.000000
# 378  YKM        2514         3.0  medium_airport      W    0.000068
# 379  YNG           2         3.0  medium_airport      M    0.000068
# 380  YUM        3295         0.0  medium_airport      W    0.000000
#
#      percentflights
# 0      7.520689e-04
# 1      7.520689e-04
# 2      2.683236e-04
# 3      3.399412e-03
# 4      9.329732e-05
# ..              ...
# 376    2.613826e-05
# 377    9.017073e-05
# 378    1.572047e-04
# 379    1.250634e-07
# 380    2.060420e-04
#
# [381 rows x 7 columns]

# %%
airports_guide = '''
IATA: Airport IATA code
numflights: Count of entries from flights table, grouped by IATA
numstrikes: Count of entries from birdstrike.csv, grouped by IATA
type: Type of airport
region: 
    N - North East
    W - West 
    M - Mid West 
    S - South 
    O - Other
strikeprob: airports.numstrikes / airports.numstrikes.sum()
percentflights: airports.numflights / airports.numflights.sum()
'''

# %%
# export airports as csv, airports_guide as txt

airports.to_csv('airports_strikes.csv')


text = open('airports_strikes_description.txt', 'w')
text.write(airports_guide)
text.close()
